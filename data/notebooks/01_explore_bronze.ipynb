# %%
import pandas as pd
from pathlib import Path

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 160)

# %%
cd C:\Deadpool\Github_files\F1-ENE-datapipeline-project
# Out:
# C:\Deadpool\Github_files\F1-ENE-datapipeline-project

# %%
BASE = Path("data/bronze/laps/season=2024")

paths = {
    "r1":  BASE / "round=1"  / "session=R" / "data.parquet",
    "rmid": BASE / "round=12" / "session=R" / "data.parquet",
    "rlast": BASE / "round=24" / "session=R" / "data.parquet",
}

for k, p in paths.items():
    print(k, "->", p, "| exists:", p.exists())
# Out:
# r1 -> data\bronze\laps\season=2024\round=1\session=R\data.parquet | exists: True
# rmid -> data\bronze\laps\season=2024\round=12\session=R\data.parquet | exists: True
# rlast -> data\bronze\laps\season=2024\round=24\session=R\data.parquet | exists: True

# %%
df1 = pd.read_parquet(paths["r1"], engine="pyarrow")
df1.shape
# Out:
# (1129, 35)

# %%
df1.head(5)
# Out:
#                     Time Driver DriverNumber                LapTime  LapNumber  Stint PitOutTime PitInTime            Sector1Time            Sector2Time  \
# 0 0 days 01:01:37.489000    VER            1 0 days 00:01:37.284000        1.0    1.0        NaT       NaT                    NaT 0 days 00:00:41.266000
# 1 0 days 01:03:13.785000    VER            1 0 days 00:01:36.296000        2.0    1.0        NaT       NaT 0 days 00:00:30.916000 0 days 00:00:41.661000
# 2 0 days 01:04:50.538000    VER            1 0 days 00:01:36.753000        3.0    1.0        NaT       NaT 0 days 00:00:30.999000 0 days 00:00:41.966000
# 3 0 days 01:06:27.185000    VER            1 0 days 00:01:36.647000        4.0    1.0        NaT       NaT 0 days 00:00:30.931000 0 days 00:00:41.892000
# 4 0 days 01:08:04.358000    VER            1 0 days 00:01:37.173000        5.0    1.0        NaT       NaT 0 days 00:00:31.255000 0 days 00:00:42.056000
#
#              Sector3Time     Sector1SessionTime     Sector2SessionTime     Sector3SessionTime  SpeedI1  SpeedI2  SpeedFL  SpeedST  IsPersonalBest Compound  \
# 0 0 days 00:00:23.616000                    NaT 0 days 01:01:13.987000 0 days 01:01:37.669000    234.0    250.0    276.0    251.0           False     SOFT
# 1 0 days 00:00:23.719000 0 days 01:02:08.426000 0 days 01:02:50.087000 0 days 01:03:13.806000    232.0    248.0    276.0    287.0            True     SOFT
# 2 0 days 00:00:23.788000 0 days 01:03:44.805000 0 days 01:04:26.771000 0 days 01:04:50.559000    231.0    243.0    276.0    290.0           False     SOFT
# 3 0 days 00:00:23.824000 0 days 01:05:21.490000 0 days 01:06:03.382000 0 days 01:06:27.206000    233.0    253.0    276.0      NaN           False     SOFT
# 4 0 days 00:00:23.862000 0 days 01:06:58.461000 0 days 01:07:40.517000 0 days 01:08:04.379000    231.0    245.0    276.0    289.0           False     SOFT
#
#    TyreLife  FreshTyre             Team           LapStartTime            LapStartDate TrackStatus  Position  Deleted DeletedReason  FastF1Generated  \
# 0       4.0      False  Red Bull Racing 0 days 00:59:59.911000 2024-03-02 15:03:42.342          12       1.0    False                          False
# 1       5.0      False  Red Bull Racing 0 days 01:01:37.489000 2024-03-02 15:05:19.920           1       1.0    False                          False
# 2       6.0      False  Red Bull Racing 0 days 01:03:13.785000 2024-03-02 15:06:56.216           1       1.0    False                          False
# 3       7.0      False  Red Bull Racing 0 days 01:04:50.538000 2024-03-02 15:08:32.969           1       1.0    False                          False
# 4       8.0      False  Red Bull Racing 0 days 01:06:27.185000 2024-03-02 15:10:09.616           1       1.0    False                          False
#
#    IsAccurate  season  event_round session_type               ingestion_ts
# 0       False    2024            1            R 2025-12-15 23:39:57.830341
# 1        True    2024            1            R 2025-12-15 23:39:57.830341
# 2        True    2024            1            R 2025-12-15 23:39:57.830341
# 3        True    2024            1            R 2025-12-15 23:39:57.830341
# 4        True    2024            1            R 2025-12-15 23:39:57.830341

# %%
df1.dtypes
# Out:
# Time                  timedelta64[ns]
# Driver                         object
# DriverNumber                   object
# LapTime               timedelta64[ns]
# LapNumber                     float64
# Stint                         float64
# PitOutTime            timedelta64[ns]
# PitInTime             timedelta64[ns]
# Sector1Time           timedelta64[ns]
# Sector2Time           timedelta64[ns]
# Sector3Time           timedelta64[ns]
# Sector1SessionTime    timedelta64[ns]
# Sector2SessionTime    timedelta64[ns]
# Sector3SessionTime    timedelta64[ns]
# SpeedI1                       float64
# SpeedI2                       float64
# SpeedFL                       float64
# SpeedST                       float64
# IsPersonalBest                   bool
# Compound                       object
# TyreLife                      float64
# FreshTyre                        bool
# Team                           object
# LapStartTime          timedelta64[ns]
# LapStartDate           datetime64[ns]
# TrackStatus                    object
# Position                      float64
# Deleted                          bool
# DeletedReason                  object
# FastF1Generated                  bool
# IsAccurate                       bool
# season                          int64
# event_round                     int64
# session_type                   object
# ingestion_ts           datetime64[us]
# dtype: object

# %%
timedelta_cols = df1.select_dtypes(include=["timedelta64[ns]"]).columns.tolist()
datetime_cols  = df1.select_dtypes(include=["datetime64[ns]"]).columns.tolist()
object_cols    = df1.select_dtypes(include=["object"]).columns.tolist()

print("timedelta cols:", timedelta_cols)
print("datetime cols:", datetime_cols)
print("object cols:", object_cols)
print("object cols count:", len(object_cols))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 timedelta_cols = df1.select_dtypes(include=["timedelta64[ns]"]).columns.tolist()
#       2 datetime_cols  = df1.select_dtypes(include=["datetime64[ns]"]).columns.tolist()
#       3 object_cols    = df1.select_dtypes(include=["object"]).columns.tolist()
#
# NameError: name 'df1' is not defined

# %%
null_rate = (df1.isna().mean().sort_values(ascending=False) * 100).round(2)
null_rate.head(25)
# Out:
# PitOutTime            96.19
# PitInTime             96.19
# SpeedI1               26.57
# SpeedST               15.06
# SpeedFL                3.81
# Sector1SessionTime     1.95
# Sector1Time            1.86
# LapTime                0.18
# DriverNumber           0.00
# Time                   0.00
# Driver                 0.00
# Sector3Time            0.00
# Sector2Time            0.00
# LapNumber              0.00
# Stint                  0.00
# Sector3SessionTime     0.00
# Sector2SessionTime     0.00
# SpeedI2                0.00
# IsPersonalBest         0.00
# Compound               0.00
# TyreLife               0.00
# FreshTyre              0.00
# Team                   0.00
# LapStartTime           0.00
# LapStartDate           0.00
# dtype: float64

# %%
expected = [
    "Driver", "LapNumber", "LapTime", "Compound", "TyreLife",
    "Stint", "PitInTime", "PitOutTime", "TrackStatus"
]
present = [c for c in expected if c in df1.columns]
missing = [c for c in expected if c not in df1.columns]

print("Present:", present)
print("Missing:", missing)
# Out:
# Present: ['Driver', 'LapNumber', 'LapTime', 'Compound', 'TyreLife', 'Stint', 'PitInTime', 'PitOutTime', 'TrackStatus']
# Missing: []

# %%
dfm = pd.read_parquet(paths["rmid"], engine="pyarrow")
dfl = pd.read_parquet(paths["rlast"], engine="pyarrow")

print("Round 1:", df1.shape)
print("Round mid:", dfm.shape)
print("Round last:", dfl.shape)
# Out:
# Round 1: (1129, 35)
# Round mid: (961, 35)
# Round last: (1035, 35)

# %%
cols1 = set(df1.columns)
colsm = set(dfm.columns)
colsl = set(dfl.columns)

print("Cols in r1 not in rmid:", sorted(cols1 - colsm)[:50])
print("Cols in rmid not in r1:", sorted(colsm - cols1)[:50])

print("Cols in r1 not in rlast:", sorted(cols1 - colsl)[:50])
print("Cols in rlast not in r1:", sorted(colsl - cols1)[:50])
# Out:
# Cols in r1 not in rmid: []
# Cols in rmid not in r1: []
# Cols in r1 not in rlast: []
# Cols in rlast not in r1: []

# %%
shared = sorted(list(cols1 & colsm & colsl))

dtype_compare = pd.DataFrame({
    "round1":  df1[shared].dtypes.astype(str),
    "roundmid": dfm[shared].dtypes.astype(str),
    "roundlast": dfl[shared].dtypes.astype(str),
})

mismatched = dtype_compare[
    (dtype_compare["round1"] != dtype_compare["roundmid"]) |
    (dtype_compare["round1"] != dtype_compare["roundlast"])
]

mismatched.head(50)
# Out:
#                round1 roundmid roundlast
# IsPersonalBest   bool     bool    object
